# %% [markdown]
# ## Assignment-4, Team-1
#
# **Chosen company stocks are as follows:**
# 1. Amazon
# 2. EXL
# 3. Microsoft

# %% [markdown]
# ### Exploratory data analysis to understand the data

# %%
# importing numpy and pandas
import numpy as np
import pandas as pd

# importing seaborn and matplotlib
import seaborn as sb
import matplotlib.pyplot as plt

# whitegrid style for the seaborn plots
sb.set_style('darkgrid') 

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# importing Amazon stocks data
dataAmazon = pd.read_csv("C:/Users/krish/Documents/Northeastern University/Fall \'21/INFO 6105 DSE/Assignment4_Group1/AMZN.csv", parse_dates=['Date'])
dataAmazon = dataAmazon.sort_values(by='Date') 
dataAmazon
# Out:
#            Date          Low         Open   Volume         High        Close  \
# 32   1997-01-07     1.510417     1.541667  1292400     1.541667     1.515625
# 54   1997-01-08     2.250000     2.343750  3588000     2.416667     2.416667
# 96   1997-01-10     3.937500     4.437500  4999200     4.500000     4.020833
# 138  1997-01-12     4.135417     4.239583  2383200     4.375000     4.270833
# 11   1997-02-06     1.500000     1.510417   591600     1.531250     1.510417
# ...         ...          ...          ...      ...          ...          ...
# 5995 2021-12-03  3045.500000  3075.000000  2421900  3098.979980  3089.489990
# 6015 2021-12-04  3351.149902  3355.209961  3281800  3395.040039  3379.389893
# 6037 2021-12-05  3133.100098  3185.000000  4936400  3207.939941  3151.939941
# 6078 2021-12-07  3696.790039  3744.000000  2571600  3757.290039  3718.550049
# 6101 2021-12-08  3269.669922  3290.000000  2314100  3314.510010  3303.500000
#
#       Adjusted_Close
# 32          1.515625
# ...

# %%
# append company name in new column
dataAmazon['Company'] = "Amazon"
dataAmazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6143 entries, 32 to 6101
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6143 non-null   datetime64[ns]
#  1   Low             6143 non-null   float64
#  2   Open            6143 non-null   float64
#  3   Volume          6143 non-null   int64
#  4   High            6143 non-null   float64
#  5   Close           6143 non-null   float64
#  6   Adjusted_Close  6143 non-null   float64
#  7   Company         6143 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 431.9+ KB

# %%
# importing EXL stocks data
dataEXL = pd.read_csv("C:/Users/krish/Documents/Northeastern University/Fall \'21/INFO 6105 DSE/Assignment4_Group1/EXLS.csv", parse_dates=['Date'])
dataEXL = dataEXL.sort_values(by='Date') 
dataEXL
# Out:
#            Date         Low        Open  Volume        High       Close  \
# 8    2006-01-11   20.000000   20.549999  111400   21.500000   20.150000
# 29   2006-01-12   22.389999   22.510000   64800   22.990000   22.430000
# 9    2006-02-11   19.559999   20.000000   79000   21.150000   20.670000
# 10   2006-03-11   19.780001   20.440001   43300   20.500000   20.299999
# 30   2006-04-12   21.980000   22.370001  141100   22.370001   22.049999
# ...         ...         ...         ...     ...         ...         ...
# 3621 2021-12-03   88.389999   89.940002  266100   90.589996   88.620003
# 3641 2021-12-04   91.440002   92.949997  122800   93.190002   93.019997
# 3663 2021-12-05   96.540001   99.400002  289400   99.730003   97.059998
# 3704 2021-12-07  106.620003  107.309998   62200  108.129997  107.570000
# 3727 2021-12-08  119.029999  120.040001  147800  120.980003  119.720001
#
#       Adjusted_Close
# 8          20.150000
# 29         22.430000
# 9          20.670000
# ...

# %%
# append company name in new column
dataEXL['Company'] = "EXL"
dataEXL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3769 entries, 8 to 3727
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            3769 non-null   datetime64[ns]
#  1   Low             3769 non-null   float64
#  2   Open            3769 non-null   float64
#  3   Volume          3769 non-null   int64
#  4   High            3769 non-null   float64
#  5   Close           3769 non-null   float64
#  6   Adjusted_Close  3769 non-null   float64
#  7   Company         3769 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 265.0+ KB

# %%
# importing Microsoft stocks data
dataMicrosoft = pd.read_csv("C:/Users/krish/Documents/Northeastern University/Fall \'21/INFO 6105 DSE/Assignment4_Group1/MSFT.csv", parse_dates=['Date'])
dataMicrosoft = dataMicrosoft.sort_values(by='Date') 
dataMicrosoft
# Out:
#            Date         Low        Open    Volume        High       Close  \
# 12   1986-01-04    0.094618    0.095486  11088000    0.095486    0.094618
# 34   1986-01-05    0.108507    0.111979  54345600    0.111979    0.110243
# 76   1986-01-07    0.105903    0.106771  47577600    0.106771    0.106771
# 98   1986-01-08    0.097222    0.098958  12902400    0.099826    0.098090
# 140  1986-01-10    0.095486    0.098090  32428800    0.099826    0.097222
# ...         ...         ...         ...       ...         ...         ...
# 8821 2021-12-03  233.229996  234.009995  22653700  235.820007  235.750000
# 8841 2021-12-04  254.619995  254.710007  27148700  257.670013  255.910004
# 8863 2021-12-05  238.070007  242.169998  36684400  244.380005  239.000000
# 8904 2021-12-07  276.579987  279.160004  18931700  279.769989  277.320007
# 8927 2021-12-08  286.339996  286.630005  14561300  289.970001  289.809998
#
#       Adjusted_Close
# 12          0.059958
# 34          0.069860
# ...

# %%
# append company name in new column
dataMicrosoft['Company'] = "Microsoft"
dataMicrosoft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8969 entries, 12 to 8927
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            8969 non-null   datetime64[ns]
#  1   Low             8969 non-null   float64
#  2   Open            8969 non-null   float64
#  3   Volume          8969 non-null   int64
#  4   High            8969 non-null   float64
#  5   Close           8969 non-null   float64
#  6   Adjusted_Close  8969 non-null   float64
#  7   Company         8969 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 630.6+ KB

# %% [markdown]
# #### Plotting the closing price of each company's stock over the years.

# %%
fig, ax = plt.subplots(3,1,figsize=(15,20))
fig.tight_layout(pad = 5)

# Amazon
ax[0].plot(dataAmazon['Date'],dataAmazon['Close'])
ax[0].set_ylabel('Close Value', fontsize=12)
ax[0].set_title("Closing price - Amazon", fontsize=12, fontweight ='bold')

# EXL 
ax[1].plot(dataEXL['Date'], dataEXL['Close'])
ax[1].set_ylabel('Close Value', fontsize=12)
ax[1].set_title("Closing price - EXL", fontsize=12, fontweight ='bold')

# Microsoft
ax[2].plot(dataMicrosoft['Date'], dataMicrosoft['Close'])
ax[2].set_ylabel('Close Value', fontsize=12)
ax[2].set_title("Closing price - Microsoft", fontsize=12, fontweight ='bold')

plt.show()

# %% [markdown]
# #### Plotting volume of sales being traded each day by each company..

# %%
fig, ax = plt.subplots(3,1,figsize=(15,20))
fig.tight_layout(pad = 5)

# Amazon
ax[0].plot(dataAmazon['Date'],dataAmazon['Volume'])
ax[0].set_ylabel('Volume', fontsize=12)
ax[0].set_title("Sales volume - Amazon", fontsize=12, fontweight ='bold')

# EXL 
ax[1].plot(dataEXL['Date'], dataEXL['Volume'])
ax[1].set_ylabel('Volume', fontsize=12)
ax[1].set_title("Sales volume - EXL", fontsize=12, fontweight ='bold')

# Microsoft
ax[2].plot(dataMicrosoft['Date'], dataMicrosoft['Volume'])
ax[2].set_ylabel('Volume', fontsize=12)
ax[2].set_title("Sales volume - Microsoft", fontsize=12, fontweight ='bold')

plt.show()

# %% [markdown]
# Calculating the daily returns using **pct_change()** function over the closing price.

# %%
# Amazon daily returns
dataAmazon['Daily_Return_Percentage'] = dataAmazon['Close'].pct_change()
dataAmazon
# Out:
#            Date          Low         Open   Volume         High        Close  \
# 32   1997-01-07     1.510417     1.541667  1292400     1.541667     1.515625
# 54   1997-01-08     2.250000     2.343750  3588000     2.416667     2.416667
# 96   1997-01-10     3.937500     4.437500  4999200     4.500000     4.020833
# 138  1997-01-12     4.135417     4.239583  2383200     4.375000     4.270833
# 11   1997-02-06     1.500000     1.510417   591600     1.531250     1.510417
# ...         ...          ...          ...      ...          ...          ...
# 5995 2021-12-03  3045.500000  3075.000000  2421900  3098.979980  3089.489990
# 6015 2021-12-04  3351.149902  3355.209961  3281800  3395.040039  3379.389893
# 6037 2021-12-05  3133.100098  3185.000000  4936400  3207.939941  3151.939941
# 6078 2021-12-07  3696.790039  3744.000000  2571600  3757.290039  3718.550049
# 6101 2021-12-08  3269.669922  3290.000000  2314100  3314.510010  3303.500000
#
# ...

# %%
dataAmazon['Daily_Return_Percentage'] = dataAmazon['Daily_Return_Percentage'].fillna(0)

# %%
# EXL daily returns
dataEXL['Daily_Return_Percentage'] = dataEXL['Close'].pct_change()
dataEXL
# Out:
#            Date         Low        Open  Volume        High       Close  \
# 8    2006-01-11   20.000000   20.549999  111400   21.500000   20.150000
# 29   2006-01-12   22.389999   22.510000   64800   22.990000   22.430000
# 9    2006-02-11   19.559999   20.000000   79000   21.150000   20.670000
# 10   2006-03-11   19.780001   20.440001   43300   20.500000   20.299999
# 30   2006-04-12   21.980000   22.370001  141100   22.370001   22.049999
# ...         ...         ...         ...     ...         ...         ...
# 3621 2021-12-03   88.389999   89.940002  266100   90.589996   88.620003
# 3641 2021-12-04   91.440002   92.949997  122800   93.190002   93.019997
# 3663 2021-12-05   96.540001   99.400002  289400   99.730003   97.059998
# 3704 2021-12-07  106.620003  107.309998   62200  108.129997  107.570000
# 3727 2021-12-08  119.029999  120.040001  147800  120.980003  119.720001
#
#       Adjusted_Close Company  Daily_Return_Percentage
# ...

# %%
dataEXL['Daily_Return_Percentage'] = dataEXL['Daily_Return_Percentage'].fillna(0)

# %%
# Microsoft daily returns
dataMicrosoft['Daily_Return_Percentage'] = dataMicrosoft['Close'].pct_change()
dataMicrosoft
# Out:
#            Date         Low        Open    Volume        High       Close  \
# 12   1986-01-04    0.094618    0.095486  11088000    0.095486    0.094618
# 34   1986-01-05    0.108507    0.111979  54345600    0.111979    0.110243
# 76   1986-01-07    0.105903    0.106771  47577600    0.106771    0.106771
# 98   1986-01-08    0.097222    0.098958  12902400    0.099826    0.098090
# 140  1986-01-10    0.095486    0.098090  32428800    0.099826    0.097222
# ...         ...         ...         ...       ...         ...         ...
# 8821 2021-12-03  233.229996  234.009995  22653700  235.820007  235.750000
# 8841 2021-12-04  254.619995  254.710007  27148700  257.670013  255.910004
# 8863 2021-12-05  238.070007  242.169998  36684400  244.380005  239.000000
# 8904 2021-12-07  276.579987  279.160004  18931700  279.769989  277.320007
# 8927 2021-12-08  286.339996  286.630005  14561300  289.970001  289.809998
#
#       Adjusted_Close    Company  Daily_Return_Percentage
# ...

# %%
dataMicrosoft['Daily_Return_Percentage'] = dataMicrosoft['Daily_Return_Percentage'].fillna(0)

# %%
fig, ax = plt.subplots(3,1,figsize=(15,20))
fig.tight_layout(pad = 5)

# Amazon
ax[0].plot(dataAmazon['Date'],dataAmazon['Daily_Return_Percentage'])
ax[0].set_ylabel('Percentage change', fontsize=12)
ax[0].set_title("Daily return - Amazon", fontsize=12, fontweight ='bold')

# EXL
ax[1].plot(dataEXL['Date'],dataEXL['Daily_Return_Percentage'])
ax[1].set_ylabel('Percentage change', fontsize=12)
ax[1].set_title("Daily return - EXL", fontsize=12, fontweight ='bold')

# Microsoft
ax[2].plot(dataMicrosoft['Date'],dataMicrosoft['Daily_Return_Percentage'])
ax[2].set_ylabel('Percentage change', fontsize=12)
ax[2].set_title("Daily return - Microsoft", fontsize=12, fontweight ='bold')
# Out:
# Text(0.5, 1.0, 'Daily return - Microsoft')

# %% [markdown]
# #### Daily returns in a univariate distribution using histograms

# %%
fig, ax = plt.subplots(3,1,figsize=(15,20))
fig.tight_layout(pad = 5)

# Amazon
sb.distplot(dataAmazon['Daily_Return_Percentage'], bins = 100, color = 'red', ax=ax[0])
ax[0].set_ylabel('')
ax[0].set_xlabel('Percentage', fontsize=12)
ax[0].set_title("Daily return - Amazon", fontsize=12, fontweight ='bold')

# EXL
sb.distplot(dataEXL['Daily_Return_Percentage'], bins = 100, color = 'purple', ax=ax[1])
ax[1].set_ylabel('')
ax[1].set_xlabel('Percentage', fontsize=12)
ax[1].set_title("Daily return - EXL", fontsize=12, fontweight ='bold')

# Microsoft
sb.distplot(dataAmazon['Daily_Return_Percentage'], bins = 100, color = 'orange', ax=ax[2])
ax[2].set_ylabel('')
ax[2].set_xlabel('Percentage', fontsize=12)
ax[2].set_title("Daily return - Microsoft", fontsize=12, fontweight ='bold')
# Out:
# Text(0.5, 1.0, 'Daily return - Microsoft')

# %% [markdown]
# ### Predicting price of stock using Random Forests

# %% [markdown]
# The independent variable (X_train) takes a subset of the dataset which only contains float values, so we drop the $Date$ and $Company$ columns for each company stock.

# %% [markdown]
# ### Amazon

# %%
# training set X
def valid(col):
    return 'Date' not in col and 'Company' not in col

X_AMZN = dataAmazon[[x for x in dataAmazon.columns if valid(x)]].iloc[0:-800]

# shifting 800 rows
y_AMZN = dataAmazon.Close.shift(-800).dropna() # removing NA

X_AMZN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5343 entries, 32 to 5408
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Low                      5343 non-null   float64
#  1   Open                     5343 non-null   float64
#  2   Volume                   5343 non-null   int64
#  3   High                     5343 non-null   float64
#  4   Close                    5343 non-null   float64
#  5   Adjusted_Close           5343 non-null   float64
#  6   Daily_Return_Percentage  5343 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 333.9 KB

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
# splitting data into test and training sets
X_train_AMZN, X_test_AMZN, y_train_AMZN, y_test_AMZN = train_test_split(X_AMZN, y_AMZN, random_state=42)

# %%
# creating a model using Random Forest Regressor
rf_model = RandomForestRegressor()

rf_model.fit(X_train_AMZN, y_train_AMZN)
# Out:
# RandomForestRegressor()

# %%
# getting score for Random Forest Regressor model for Amazon stock dataset
rf_model.score(X_test_AMZN, y_test_AMZN)
# Out:
# 0.9634439017805464

# %% [markdown]
# Amazon stock prediction model gives a score of 96%!

# %%
# predicted values
y_predicted_AMZN = rf_model.predict(X_test_AMZN)
y_predicted_AMZN[0:20]
# Out:
# array([  38.45710032,  285.90559783,  680.46469667,  193.0157972 ,
#          12.37860001,   67.55170036,   97.8188002 , 3322.17299792,
#         149.16979999, 1115.79549494,   63.66989996,  120.33369896,
#          77.73770005,   42.97499962,   62.90260008,   43.62329971,
#         682.83610414,   32.131875  , 1460.34009632,   62.93599951])

# %%
# plot of predicted values
plt.plot(y_predicted_AMZN)

# %% [markdown]
# ### EXL

# %%
# training set X
def valid(col):
    return 'Date' not in col and 'Company' not in col

X_EXL = dataEXL[[x for x in dataEXL.columns if valid(x)]].iloc[0:-800]

# shifting 800 rows
y_EXL = dataEXL.Close.shift(-800).dropna() # removing NA

X_EXL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2969 entries, 8 to 3034
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Low                      2969 non-null   float64
#  1   Open                     2969 non-null   float64
#  2   Volume                   2969 non-null   int64
#  3   High                     2969 non-null   float64
#  4   Close                    2969 non-null   float64
#  5   Adjusted_Close           2969 non-null   float64
#  6   Daily_Return_Percentage  2969 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 185.6 KB

# %%
# splitting data into test and training sets
X_train_EXL, X_test_EXL, y_train_EXL, y_test_EXL = train_test_split(X_EXL, y_EXL, random_state=42)

# %%
# creating a model using Random Forest Regressor
rf_model.fit(X_train_EXL, y_train_EXL)
# Out:
# RandomForestRegressor()

# %%
# getting score for Random Forest Regressor model for EXL stock dataset
rf_model.score(X_test_EXL, y_test_EXL)
# Out:
# 0.8480734317796823

# %% [markdown]
# EXL stock prediction model gives a score close to 84%!

# %%
# predicted values
y_predicted_EXL = rf_model.predict(X_test_EXL)
y_predicted_EXL[0:20]
# Out:
# array([72.92949963, 25.69680008, 68.05209965, 21.20609983, 26.97970001,
#        50.58080009, 26.55530029, 27.00980013, 96.40039986, 25.10139999,
#        25.45230015, 38.20439999, 34.1759    , 67.48860035, 27.69869959,
#        63.13629955, 39.76270004, 49.1711005 , 40.99269993, 19.02290001])

# %%
# plot of predicted values
plt.plot(y_predicted_EXL)

# %% [markdown]
# ### Microsoft

# %%
# training set X
def valid(col):
    return 'Date' not in col and 'Company' not in col

X_MSFT = dataMicrosoft[[x for x in dataEXL.columns if valid(x)]].iloc[0:-800]

# shifting 800 rows
y_MSFT = dataMicrosoft.Close.shift(-800).dropna() # removing NA

X_MSFT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8169 entries, 12 to 8234
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Low                      8169 non-null   float64
#  1   Open                     8169 non-null   float64
#  2   Volume                   8169 non-null   int64
#  3   High                     8169 non-null   float64
#  4   Close                    8169 non-null   float64
#  5   Adjusted_Close           8169 non-null   float64
#  6   Daily_Return_Percentage  8169 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 510.6 KB

# %%
# splitting data into test and training sets
X_train_MSFT, X_test_MSFT, y_train_MSFT, y_test_MSFT = train_test_split(X_MSFT, y_MSFT, random_state=42)

# %%
# creating a model using Random Forest Regressor
rf_model.fit(X_train_MSFT, y_train_MSFT)
# Out:
# RandomForestRegressor()

# %%
# getting score for Random Forest Regressor model for EXL stock dataset
rf_model.score(X_test_MSFT, y_test_MSFT)
# Out:
# 0.9780091527428778

# %% [markdown]
# Microsoft stock prediction model gives a score close to 97%!

# %%
# predicted values
y_predicted_MSFT = rf_model.predict(X_test_MSFT)
y_predicted_MSFT[0:20]
# Out:
# array([ 26.40789991,  33.99440018,   2.22138455,  46.871875  ,
#         27.8471002 ,   2.63570331, 274.30290054,  30.34310011,
#         31.02701238,  36.900625  ,  50.94989986, 285.32808993,
#         27.15554979,  29.79347498,  20.09882823,  29.15495007,
#         30.80080004,  26.70570005, 155.25520157,  27.91260004])

# %%
# plot of predicted values
plt.plot(y_predicted_MSFT)
